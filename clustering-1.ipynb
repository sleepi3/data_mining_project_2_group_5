# %% [markdown]
# # Imports

# %%
k_values = [2, 3, 4, 5, 6]
sil_scores = []

for k in k_values:
    result = k_means(X_scaled, n_clusters=k)
    sil_scores.append(result["silhouette_score"])

print("Silhouette scores:", list(zip(k_values, sil_scores)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 sil_scores = []
#       4 for k in k_values:
# ----> 5     result = k_means(X_scaled, n_clusters=k)
#       6     sil_scores.append(result["silhouette_score"])
#       8 print("Silhouette scores:", list(zip(k_values, sil_scores)))
#
# NameError: name 'k_means' is not defined

# %%
plt.figure(figsize=(6,4))
plt.plot(k_values, sil_scores, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("K-Means: Silhouette Score vs k")
plt.grid(True)
plt.show()

# %%
linkage_methods = ["ward", "complete", "average"]
hier_scores = []

for method in linkage_methods:
    result = hierarchical(X_scaled, n_clusters=3, linkage_method=method)
    hier_scores.append(result["silhouette_score"])

print("Hierarchical scores:", list(zip(linkage_methods, hier_scores)))

# %%
plot_dendrogram(X_scaled, method="ward")

# %%
plot_dendrogram(X_scaled, method="complete")

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

kmeans_result = k_means(X_scaled, n_clusters=3)

plot_clusters_2d(
    X_pca,
    kmeans_result["labels"],
    ["PC1", "PC2"],
    "K-Means Clusters (PCA Projection)"
)

# %%
df_kmeans = attach_cluster_labels(df, kmeans_result["labels"], "KMeans_Cluster")

print_cluster_members(df_kmeans, id_cols, "KMeans_Cluster")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import cdist

# %%
file_path = "Longotor1delta.xls"
df = pd.read_excel(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 file_path = "Longotor1delta.xls"
# ----> 2 df = pd.read_excel(file_path)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Longotor1delta.xls'

# %% [markdown]
# # Data Import

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/chimaonochie/Downloads/Longotor1delta.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_excel("/Users/chimaonochie/Downloads/Longotor1delta.xls")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/chimaonochie/Downloads/Longotor1delta.xls'

# %%
import os
print(os.listdir("/Users/chimaonochie/Downloads"))
# Out:
# ['3381_syllabus_F25.doc', 'IMBD_DDL.sql', '03_2 Describing Syntax.txt', 'brown-leather-boots-illustration', 'CSCI2320-DS-AlgoAnalysis.pptx', 'IMG_8892.jpg', 'import networkx as nx.py', 'MobileOS_Presentation_Info_Fa25 (1).doc', 'googlechrome.dmg', 'In Class Exercise-Trees-key.docx', 'CSCI2320-DS-HashTables-problems.pdf', 'CSCI2320-DS-HashTables-problems.pptx', '5d036fb8-9111-49bd-bf54-a779ea643a4a.JPG', 'IMG_0809.jpg', 'WRITER,OSCAR,AND TV HOW RELATIONSHIP _250217_182504.pdf', 'POP Homework 3.pdf', '47ADFA56-2D23-49FB-8703-C54E9A973BB4.JPG', 'Chapter 3 ER(2).txt', 'test.sql', 'POP Homework 2.pdf', 'firstDayf23 (1).doc', 'CSCI2320-DS-Ch6-List(1).pptx', 'lab-bst-conochie', 'principles of programming languages assignment 1 -2.pdf', 'Sourcetree.app', 'pendulum.xlsx', 'Graph-worksheet-key(1).pptx', 'Phase_1.pdf', 'Headers and footers assignment.docx', 'macfiles (1).zip', 'sounds (3)', 'sounds (1).zip', 'Practice Exam 1 DB with key.pdf', 'CSCI2320-DS-HashTables-problems 2.pptx', 'exam1 review.ppt', 'datamining.pg.jpg', 'PHOTO-2022-10-12-08-08-12.jpg', '02_cryptography.pptx', 'project-ds-lists-conochie-1', 'AVL Tree Exercise-key.docx', 'Report .pdf', 'Resume_Alexander Oko_ updated June 2025.docx', 'Review1.doc', 'Complete_ER_Diagram.png', 'newfile.txt.save', 'Final Paper.pdf', 'CSCI2320-DS-Intro-Trees.pptx', 'OperaGXSetup (3).zip', 'Lab06_Report_template (1).docx', 'D9BE2810-207B-4D12-A2C9-43ADA9D9D18D.JPG', 'Group 5-Ecommerce_Consumer_Behavior_Analysis_Data (1).csv', '94374E40-D9BD-4DEA-84D4-4FCF7F6D5669 2.JPG', 'IMG_8660.jpg', 'CSCI3360 Project 2 Rubric.doc', 'Graph-worksheet-key(1).pdf', 'C9609020-6083-4BDB-8683-78FA15645B07.JPG', 'IMG_7962.jpg', 'Final_3370.docx', 'Pascal Programming Language Report.pdf', 'get-pip', 'CSCI2320-DS-AVL.pdf', 'program2bat (1)', 'transcript.txt', 'Program lang hw2 CGFS.pdf', 'Case Analysis Stratification around the world.pdf', 'Case 3.pdf', 'CSC 3360 Database Systems Project 1 v1(1) (1).pdf', 'Brief Reporrt Info Sec.pdf', 'brown-leather-boots-illustration.zip', 'In Class Exercise-Trees.docx', 'Algorithms Project 1 Report.pdf', '.DS_Store', 'OperaGXSetup (2).zip', 'project-ds-lists-conochie', 'DBMS assignment .docx', 'POP Homework 4.pdf', 'your mom.JPG', '3Y9XAE6_app_slip.pdf', 'Group 5-Ecommerce_Consumer_Behavior_Analysis_Data.csv', 'workspace.code-workspace', 'tree-traversal-new-answers.docx', 'sounds.zip', 'CSCI2320-DS-BST.pdf', '4d2988a8-060b-4126-ab1b-09a749e7889e.JPG', 'project-ds-lists-conochie-main', 'Crafter pro_ Coming Soon.jpg', 'Exam 1 DB key 2020 21 22 fall.doc', 'Aesthetic cover letter (1).pdf', 'search-group-project-group-5', 'AI notes on supervised learning .pdf', 'chapter_8 stratification_final Online (2).pptx', 'macProg3', 'tree-traversal-new.docx', 'stackandqueue-exercises-2-key(1).docx', 'CSCI2320-DS-Ch7-Stack.pptx', 'IMG_FBD998B4B476-1.jpeg', 'Lab06_Report_template.docx', 'ch02.ppt', 'Practice Exam 1 DB.doc', 'ProgrammingAssignment5_fixed (1).jar', 'updated resume.pdf', 'search-group-project-group-5-1', 'Java prog assignment 2 .docx', 'project-bst-conochie', 'A1 hacking report (1).pdf', 'Chima Onochie -Updated Ebay Resume (1).pdf', 'rsa-flowchart-svg.svg', 'Provocation paper.pdf', 'IMG_8510.jpg', 'Gabriella-Uwadiegwu-Resume.pdf', 'Lab03_Report_template.docx', 'SquareGame.jack', '.localized', '454e96f3-7f68-49ec-8f07-5fa5f8742a3c.JPG', 'Untitled document.pdf', 'HashTable.h', 'Case Analysis_Stratification in USA.pdf', 'Ted and Zelda case .pdf', 'Chima Onochie - Resume .pdf', 'Lab01_Report_template(1).docx', 'Nigerian Immigration Services | Passport.pdf', 'java ARM64 DMG installer.dmg', 'Practice Exam 2 DB key.doc', 'test(3).sql', 'Project 1 DBMS Report .docx', 'Motif 3_Alice.pdf', 'lab-lists-conochie', 'company and branding details.pdf', 'IMG_7123.jpg', 'IMG_8576.jpg', 'mermaid-history-2025-02-09-200901.json', 'OperaGXSetup (5).zip', 'AVL Tree Exercise.docx', 'CSCI2320-DS-AVL 2.pptx', 'Proper outline (1).pdf', 'OperaGXSetup.zip', 'rsa-cryptosystem-flowchart.mermaid', 'd8065fe2-2ec3-4 ...

# %%
import os

files = os.listdir("/Users/chimaonochie/Downloads")

matches = [f for f in files if "long" in f.lower()]
print(matches)
# Out:
# []

# %%
df = pd.read_excel("PASTE_FULL_PATH_HERE")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_excel("PASTE_FULL_PATH_HERE")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PASTE_FULL_PATH_HERE'

# %%
import os
print(os.listdir("/Users/chimaonochie/Downloads"))
# Out:
# ['3381_syllabus_F25.doc', 'IMBD_DDL.sql', '03_2 Describing Syntax.txt', 'brown-leather-boots-illustration', 'CSCI2320-DS-AlgoAnalysis.pptx', 'IMG_8892.jpg', 'import networkx as nx.py', 'MobileOS_Presentation_Info_Fa25 (1).doc', 'googlechrome.dmg', 'In Class Exercise-Trees-key.docx', 'CSCI2320-DS-HashTables-problems.pdf', 'CSCI2320-DS-HashTables-problems.pptx', '5d036fb8-9111-49bd-bf54-a779ea643a4a.JPG', 'IMG_0809.jpg', 'WRITER,OSCAR,AND TV HOW RELATIONSHIP _250217_182504.pdf', 'POP Homework 3.pdf', '47ADFA56-2D23-49FB-8703-C54E9A973BB4.JPG', 'Chapter 3 ER(2).txt', 'test.sql', 'POP Homework 2.pdf', 'firstDayf23 (1).doc', 'CSCI2320-DS-Ch6-List(1).pptx', 'lab-bst-conochie', 'principles of programming languages assignment 1 -2.pdf', 'Sourcetree.app', 'pendulum.xlsx', 'Graph-worksheet-key(1).pptx', 'Phase_1.pdf', 'Headers and footers assignment.docx', 'macfiles (1).zip', 'sounds (3)', 'sounds (1).zip', 'Practice Exam 1 DB with key.pdf', 'CSCI2320-DS-HashTables-problems 2.pptx', 'exam1 review.ppt', 'datamining.pg.jpg', 'PHOTO-2022-10-12-08-08-12.jpg', '02_cryptography.pptx', 'project-ds-lists-conochie-1', 'AVL Tree Exercise-key.docx', 'Report .pdf', 'Resume_Alexander Oko_ updated June 2025.docx', 'Review1.doc', 'Complete_ER_Diagram.png', 'newfile.txt.save', 'Final Paper.pdf', 'CSCI2320-DS-Intro-Trees.pptx', 'OperaGXSetup (3).zip', 'Lab06_Report_template (1).docx', 'D9BE2810-207B-4D12-A2C9-43ADA9D9D18D.JPG', 'Group 5-Ecommerce_Consumer_Behavior_Analysis_Data (1).csv', '94374E40-D9BD-4DEA-84D4-4FCF7F6D5669 2.JPG', 'IMG_8660.jpg', 'CSCI3360 Project 2 Rubric.doc', 'Graph-worksheet-key(1).pdf', 'C9609020-6083-4BDB-8683-78FA15645B07.JPG', 'IMG_7962.jpg', 'Final_3370.docx', 'Pascal Programming Language Report.pdf', 'get-pip', 'CSCI2320-DS-AVL.pdf', 'program2bat (1)', 'transcript.txt', 'Program lang hw2 CGFS.pdf', 'Case Analysis Stratification around the world.pdf', 'Case 3.pdf', 'CSC 3360 Database Systems Project 1 v1(1) (1).pdf', 'Brief Reporrt Info Sec.pdf', 'brown-leather-boots-illustration.zip', 'In Class Exercise-Trees.docx', 'Algorithms Project 1 Report.pdf', '.DS_Store', 'OperaGXSetup (2).zip', 'project-ds-lists-conochie', 'DBMS assignment .docx', 'POP Homework 4.pdf', 'your mom.JPG', '3Y9XAE6_app_slip.pdf', 'Group 5-Ecommerce_Consumer_Behavior_Analysis_Data.csv', 'workspace.code-workspace', 'tree-traversal-new-answers.docx', 'sounds.zip', 'CSCI2320-DS-BST.pdf', '4d2988a8-060b-4126-ab1b-09a749e7889e.JPG', 'project-ds-lists-conochie-main', 'Crafter pro_ Coming Soon.jpg', 'Exam 1 DB key 2020 21 22 fall.doc', 'Aesthetic cover letter (1).pdf', 'search-group-project-group-5', 'AI notes on supervised learning .pdf', 'chapter_8 stratification_final Online (2).pptx', 'macProg3', 'tree-traversal-new.docx', 'stackandqueue-exercises-2-key(1).docx', 'CSCI2320-DS-Ch7-Stack.pptx', 'IMG_FBD998B4B476-1.jpeg', 'Lab06_Report_template.docx', 'ch02.ppt', 'Practice Exam 1 DB.doc', 'ProgrammingAssignment5_fixed (1).jar', 'updated resume.pdf', 'search-group-project-group-5-1', 'Java prog assignment 2 .docx', 'project-bst-conochie', 'A1 hacking report (1).pdf', 'Chima Onochie -Updated Ebay Resume (1).pdf', 'rsa-flowchart-svg.svg', 'Provocation paper.pdf', 'IMG_8510.jpg', 'Gabriella-Uwadiegwu-Resume.pdf', 'Lab03_Report_template.docx', 'SquareGame.jack', '.localized', '454e96f3-7f68-49ec-8f07-5fa5f8742a3c.JPG', 'Untitled document.pdf', 'HashTable.h', 'Case Analysis_Stratification in USA.pdf', 'Ted and Zelda case .pdf', 'Chima Onochie - Resume .pdf', 'Lab01_Report_template(1).docx', 'Nigerian Immigration Services | Passport.pdf', 'java ARM64 DMG installer.dmg', 'Practice Exam 2 DB key.doc', 'test(3).sql', 'Project 1 DBMS Report .docx', 'Motif 3_Alice.pdf', 'lab-lists-conochie', 'company and branding details.pdf', 'IMG_7123.jpg', 'IMG_8576.jpg', 'mermaid-history-2025-02-09-200901.json', 'OperaGXSetup (5).zip', 'AVL Tree Exercise.docx', 'CSCI2320-DS-AVL 2.pptx', 'Proper outline (1).pdf', 'OperaGXSetup.zip', 'rsa-cryptosystem-flowchart.mermaid', 'd8065fe2-2ec3-4 ...

# %%
import pandas as pd

df = pd.read_excel("/Users/chimaonochie/Downloads/Longotor1delta.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel("/Users/chimaonochie/Downloads/Longotor1delta.xls")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_xlrd.py:45, in XlrdReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#      33 """
#      34 Reader using xlrd engine.
#      35
#    (...)
#      42     Arbitrary keyword arguments passed to excel engine.
#      43 """
#      44 err_msg = "Install xlrd >= 2.0.1 for xls Excel support"
# ---> 45 import_optional_dependency("xlrd", extra=err_msg)
#      46 super().__init__(
#      47     filepath_or_buffer,
#      48     storage_options=storage_options,
#      49     engine_kwargs=engine_kwargs,
#      50 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.

# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_excel(
    "/Users/chimaonochie/Downloads/Longotor1delta.xls",
    engine="xlrd"
)

# %%
df.head()
# Out:
#   Public ID        Gene                                   Gene description  \
# 0   YAL001C        TFC3  Largest of six subunits of the RNA polymerase ...
# 1   YAL002W        VPS8  Membrane-associated hydrophilic protein that i...
# 2   YAL003W        EFB1  Translation elongation factor 1 beta, stimulat...
# 3   YAL005C  SSA2  SSA1  ATP binding protein involved in protein foldin...
# 4   YAL007C        ERP2  Protein that forms a heterotrimeric complex wi...
#
#     sch9/wt   ras2/wt   tor1/wt  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0 -0.330611 -0.591746 -0.405035         NaN         NaN         NaN
# 1  0.043376 -0.113738  0.006602         NaN         NaN         NaN
# 2  0.457423  0.305146  0.425690         NaN         NaN         NaN
# 3  0.404616  0.526297  0.540533         NaN         NaN         NaN
# 4  0.261135  0.609976  0.468309         NaN         NaN         NaN

# %%
feature_cols = ["sch9/wt", "ras2/wt", "tor1/wt"]

X = df[feature_cols].values

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

k_values = [2, 3, 4, 5, 6]
sil_scores = []

for k in k_values:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = model.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    sil_scores.append(score)

list(zip(k_values, sil_scores))
# Out:
# [(2, np.float64(0.410022910487096)),
#  (3, np.float64(0.3625497943329255)),
#  (4, np.float64(0.3258843630373519)),
#  (5, np.float64(0.2982103028707852)),
#  (6, np.float64(0.28108892761214954))]

# %%
import matplotlib.pyplot as plt

plt.plot(k_values, sil_scores, marker='o')
plt.title("K-Means Silhouette Score vs K")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

def hierarchical(X, n_clusters=3, linkage="ward"):
    model = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
    labels = model.fit_predict(X)
    score = silhouette_score(X, labels)

    return labels, score

# %%
hier_labels, hier_score = hierarchical(X_scaled, 3)

print("Hierarchical Silhouette Score:", hier_score)
# Out:
# Hierarchical Silhouette Score: 0.33886210922513077

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

linked = linkage(X_scaled, method="ward")

plt.figure(figsize=(10,5))
dendrogram(linked, no_labels=True)
plt.title("Hierarchical Clustering Dendrogram")
plt.show()

# %%
kmeans_model = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans_labels = kmeans_model.fit_predict(X_scaled)

print("KMeans:", silhouette_score(X_scaled, kmeans_labels))
print("Hierarchical:", hier_score)
# Out:
# KMeans: 0.3625497943329255
# Hierarchical: 0.33886210922513077

# %%
#import to dataframe
file_path = "Longotor1delta.xls"
df = pd.read_excel(file_path)

#preview of dataset
print("First 5 rows:")
print(df.head())
print("\nColumns:")
print(df.columns.tolist())
print("\nShape:")
print(df.shape)
# Out:
# First 5 rows:
#   Public ID        Gene                                   Gene description  \
# 0   YAL001C        TFC3  Largest of six subunits of the RNA polymerase ...
# 1   YAL002W        VPS8  Membrane-associated hydrophilic protein that i...
# 2   YAL003W        EFB1  Translation elongation factor 1 beta, stimulat...
# 3   YAL005C  SSA2  SSA1  ATP binding protein involved in protein foldin...
# 4   YAL007C        ERP2  Protein that forms a heterotrimeric complex wi...
#
#     sch9/wt   ras2/wt   tor1/wt  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0 -0.330611 -0.591746 -0.405035         NaN         NaN         NaN
# 1  0.043376 -0.113738  0.006602         NaN         NaN         NaN
# 2  0.457423  0.305146  0.425690         NaN         NaN         NaN
# 3  0.404616  0.526297  0.540533         NaN         NaN         NaN
# 4  0.261135  0.609976  0.468309         NaN         NaN         NaN
#
# Columns:
# ['Public ID', 'Gene', 'Gene description', 'sch9/wt', 'ras2/wt', 'tor1/wt', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']
#
# Shape:
# (5667, 9)

# %% [markdown]
# # Data Cleaning
# We identified the columns used for identification and the three columns containing numeric data about the genes. We removed all other columns, 'Unnamed: 6', 'Unnamed: 7', and 'Unnamed: 8', then dropped all N/A values. We normalized the numerical data with StandardScalar to ensure they are comparible for accurate clustering.

# %%
#keep needed columns
id_cols = ["Public ID", "Gene", "Gene description"]
feature_cols = ["sch9/wt", "ras2/wt", "tor1/wt"]
df = df[id_cols + feature_cols].copy()
#drop missing values
df = df.dropna(subset=feature_cols)
print("\nCleaned dataset shape:")
print(df.shape)
# Out:
# Cleaned dataset shape:
# (5667, 6)

# %%
#isolate columns with numerical data
X = df[feature_cols].values
#scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("\nFirst 5 rows of normalized data:")
print(X_scaled[:5])
# Out:
# First 5 rows of normalized data:
# [[-0.67404716 -0.81083905 -0.93142952]
#  [ 0.09967535 -0.0915476  -0.02340987]
#  [ 0.95627538  0.53877375  0.90104548]
#  [ 0.84702556  0.87155555  1.15437581]
#  [ 0.55018509  0.99747205  0.99505882]]

# %%
def k_means(X, n_clusters=3, random_state=13, n_init=10):
    """runs and reports results of k means clustering on input dataset"""

    model = KMeans(n_clusters=n_clusters, random_state=random_state, n_init=n_init)
    labels = model.fit_predict(X)

    result = {
        "model": model,
        "labels": labels, 
        "silhouette_score": silhouette_score(X, labels) if n_clusters > 1 else None,
        "cluster_centers": model.cluster_centers_
    }
    return result

# %%
result = k_means(X_scaled, n_clusters=3)

print(result["silhouette_score"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = k_means(X_scaled, n_clusters=3)
#       3 print(result["silhouette_score"])
#
# NameError: name 'X_scaled' is not defined

# %%
def hierarchical(X, n_clusters=3, linkage_method="ward", distance_metric="euclidean"):
    """runs and reports results of agglomerative hierarchical clustering on input dataset
        Note: ward linkage only works with euclidean distance"""
    
    if linkage_method == "ward" and distance_metric != "euclidean":
        raise ValueError("Ward linkage only supports euclidean distance.")

    model = AgglomerativeClustering(
        n_clusters=n_clusters,
        metric=distance_metric,
        linkage=linkage_method
    )
    labels = model.fit_predict(X)

    result = {
        "model": model,
        "labels": labels,
        "silhouette_score": silhouette_score(X, labels) if n_clusters > 1 else None
    }
    return result

# %%
def attach_cluster_labels(df, labels, cluster_col_name="Cluster"):
    """
    Attach cluster labels back to the original dataframe.
    """
    df_copy = df.copy()
    df_copy[cluster_col_name] = labels
    return df_copy


def print_cluster_members(df, id_cols, cluster_col_name="Cluster", max_rows=10):
    """
    Print sample members from each cluster.
    """
    for cluster_id in sorted(df[cluster_col_name].unique()):
        print(f"\nCluster {cluster_id}")
        print(df[df[cluster_col_name] == cluster_id][id_cols].head(max_rows))

# %% [markdown]
# ### Visualization Helper Functions

# %%
def plot_clusters_2d(X, labels, feature_cols, title):
    """
    Plot first two features for quick cluster visualization.
    """
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=labels)
    plt.xlabel(feature_cols[0])
    plt.ylabel(feature_cols[1])
    plt.title(title)
    plt.grid(True)
    plt.show()


def plot_dendrogram(X, method="ward"):
    """
    Plot dendrogram for hierarchical clustering.
    """
    linked = linkage(X, method=method)
    plt.figure(figsize=(12, 6))
    dendrogram(linked, no_labels=True)
    plt.title(f"Dendrogram ({method} linkage)")
    plt.xlabel("Data Points")
    plt.ylabel("Distance")
    plt.show()

# %%
kmeans_result = k_means(X_scaled)
plot_clusters_2d(X_scaled, kmeans_result["labels"], feature_cols, "K-Means (k=3)")

# %%
df_kmeans = attach_cluster_labels(df, kmeans_result["labels"], "KMeans_Cluster")
print_cluster_members(df_kmeans, id_cols, "KMeans_Cluster")
# Out:
# Cluster 0
#     Public ID   Gene                                   Gene description
# 1     YAL002W   VPS8  Membrane-associated hydrophilic protein that i...
# 6     YAL009W   SPO7  Integral nuclearER membrane protein of unknown...
# 7     YAL010C  MDM10  Subunit of the mitochondrial sorting and assem...
# 10    YAL013W   DEP1  Transcriptional modulator involved in the regu...
# 12    YAL015C   NTG1  DNA N-glycosylase and apurinicapyrimidinic (AP...
# 13  YAL016C-B    ---           Identified by fungal homology and RT-PCR
# 14    YAL016W   TPD3  Regulatory subunit A of the heterotrimeric pro...
# 16    YAL018C    ---                               Hypothetical protein
# 18    YAL020C   ATS1  Protein with a potential role in regulatory in...
# 19    YAL021C   CCR4  Component of the CCR4-NOT transcriptional comp...
#
# Cluster 1
#    Public ID   Gene                                   Gene description
# 0    YAL001C   TFC3  Largest of six subunits of the RNA polymerase ...
# 8    YAL011W   SWC3  Protein of unknown function, component of the ...
# 15   YAL017W   PSK1  One of two (see also PSK2) PAS domain containi...
# 17   YAL019W  FUN30  Protein whose overexpression affects chromosom...
# 21   YAL023C   PMT2  Protein O-mannosyltransferase, transfers manno...
# 23   YAL025C  MAK16  Essential nuclear protein, constituent of 66S ...
# 30   YAL032C  PRP45  Ortholog of human transcriptional coactivator ...
# 41   YAL041W  CDC24  Guanine nucleotide exchange factor (GEF or GDP...
# 46   YAL046C    ---                               Hypothetical protein
# 52   YAL054C   ACS1  Acetyl-coA synthetase isoform, expressed durin...
#
# Cluster 2
#     Public ID        Gene                                   Gene description
# 2     YAL003W        EFB1  Translation elongation factor 1 beta, stimulat...
# 3     YAL005C  SSA2  SSA1  ATP binding protein involved in protein foldin...
# 4     YAL007C        ERP2  Protein that forms a heterotrimeric complex wi...
# 5     YAL008W       FUN14          Mitochondrial protein of unknown function
# 9     YAL012W        CYS3  Cystathionine gamma-lyase, catalyzes one of th...
# 11    YAL014C        SYN8    Endosomal SNARE related to mammalian syntaxin 8
# 26    YAL028W        FRT2  Tail-anchored endoplasmic reticulum membrane p...
# 28    YAL030W        SNC1  Vesicle membrane receptor protein (v-SNARE) in...
# 36  YAL037C-A         ---                                 Identified by SAGE
# 37    YAL037W         ---                               Hypothetical protein
